# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in c:\personal files\installation\anaconda\envs\akhil_env_3_11\lib\site-packages (0.25.1)

# %%
# Importing the necessary library
import librosa
import pandas as pd
import os

# %%
# Function to get the total number of mp3 files in a folder
def count_mp3_files(folder_path):
    mp3_files = [file for file in os.listdir(folder_path) if file.endswith('.mp3')]
    return len(mp3_files)

# Function to get the total number of mp3 files in all folders
def total_mp3_files_in_folders(root_folder):
    total_mp3_files = 0
    for folder_name in os.listdir(root_folder):
        folder_path = os.path.join(root_folder, folder_name)
        if os.path.isdir(folder_path):
            total_mp3_files += count_mp3_files(folder_path)
    return total_mp3_files


root_folder_path = 'E:\\personal files\\dataset\\archive_8\\Language Detection Dataset'

total_mp3_files = total_mp3_files_in_folders(root_folder_path)

print(f'Total number of .mp3 files in all folders: {total_mp3_files}')
# Out:
# Total number of .mp3 files in all folders: 256833

# %%
# verify if any other formats are available other than .mp3

import os
from collections import Counter

def count_files_by_type(folder_path):
    file_types_counter = Counter()

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            _, file_extension = os.path.splitext(file)
            file_types_counter[file_extension.lower()] += 1

    return file_types_counter

def print_file_counts(folder_path):
    file_counts = count_files_by_type(folder_path)

    print(f"File counts in {folder_path}:")
    for file_type, count in file_counts.items():
        print(f"{file_type}: {count}")

# Example usage:
folder_path = "E:\\personal files\\dataset\\archive_8\\Language Detection Dataset"
print_file_counts(folder_path)
# Out:
# File counts in E:\personal files\dataset\archive_8\Language Detection Dataset:
# .mp3: 256833

# %%
# Number of audio files in each folder
import os
d={}
def count_audio_files(folder_path):
    audio_files_count = 0

    for root, dirs, files in os.walk(folder_path):
        audio_files = [file for file in files if file.lower().endswith((".mp3"))]
        audio_files_count += len(audio_files)

        folder_name = os.path.basename(root)
        if folder_name=="":
            continue
        print(f"Folder: {folder_name}, Audio Files: {len(audio_files)}")
        d[folder_name]=len(audio_files)
    return audio_files_count

def print_total_audio_files(folder_path):
    total_audio_files = count_audio_files(folder_path)
    print(f"\nTotal Audio Files across all folders: {total_audio_files}")

# Example usage:
folder_path = "E:\\personal files\\dataset\\archive_8\\Language Detection Dataset\\"
print_total_audio_files(folder_path)


# min_value = min(d.values())
# print("\nThe minimum no of audio files is:- ",min_value)

#print the language having less data
min_key = min(d, key=d.get)
min_value = d[min_key]

print("\nThe minimum number of audio files is:", min_value, "for the language:", min_key)
# Out:
# Folder: Bengali, Audio Files: 27258
# Folder: Gujarati, Audio Files: 26441
# Folder: Hindi, Audio Files: 25462
# Folder: Kannada, Audio Files: 22208
# Folder: Malayalam, Audio Files: 24044
# Folder: Marathi, Audio Files: 25379
# Folder: Punjabi, Audio Files: 26229
# Folder: Tamil, Audio Files: 24196
# Folder: Telugu, Audio Files: 23656
# Folder: Urdu, Audio Files: 31960
#
# Total Audio Files across all folders: 256833
#
# The minimum number of audio files is: 22208 for the language: Kannada

# %%
# function to extract the relevant features of an audio file
def extract_features(audio_file):
    # Load audio file
    y, sr = librosa.load(audio_file) #The sampling rate --- typically fs in the digital signal processing literature, or sr in librosa. 
                                    # The sampling rate (sr) is defined as 1/ts, where ts is the amount of time (in seconds) between successive samples.
        
    # print("The sample rate of the {} is:- {}".format(audio_file,sr))
        
# Extract features using librosa
    # Compute a chromagram from a waveform or power spectrogram and return as numpy array.    
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr) 

    # Compute root-mean-square (RMS) value from the audio samples y.
    rmse = librosa.feature.rms(y=y) 
    
    # The spectral centroid indicates at which frequency the energy of a spectrum is centered upon 
    # or in other words It indicates where the ” center of mass” for a sound is located.
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)  
    
    # The spectrum of a signal is the range of frequencies contained in the signal. 
    # The bandwidth is the difference between the lowest and highest frequency in the spectrum.
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)

    # spectral_rolloff measures the bandwidth of the audio signal by determining the frequency bin under which a given percentage of the total energy exists 
    spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    
    # The mel frequency cepstral coefficients (MFCCs) of an audio signal are a small set of features (usually about 10–20) which describe the overall shape of the spectral envelope.
    mfccs = librosa.feature.mfcc(y=y, sr=sr)

    # compute the mean values for the extracted features and store is as a list
    features = [chroma_stft.mean(), rmse.mean(), spectral_centroid.mean(),
                spectral_bandwidth.mean(), spectral_rolloff.mean()] + mfccs.mean(axis=1).tolist()

    return features

# %%
# function to access the audio files stored locally and then extract the features of each audio file using the extract_features function
def process_audio_files(root_folder):
    features_list = []

    for folder_name in os.listdir(root_folder): # iterate through all the folders in the root folder
        folder_path = os.path.join(root_folder, folder_name) 
        # print(folder_path)
        count = 1
        if os.path.isdir(folder_path):
            print(folder_path)
            for file_name in os.listdir(folder_path): # iterate through all the contents/files in the folder
                if (file_name.endswith(".mp3") and count<=20000): # access all the audio files (.mp3 format) in each folder
                    audio_path = os.path.join(folder_path, file_name)
                    print("audio_path:- ",audio_path)
                    try:
                        features = extract_features(audio_path) # extract the features of the audio file
                        features_list.append(features + [folder_name])
                        print("Audio Foder: {} and File Name: {} is successfully extracted".format(folder_name,file_name))
                        count+=1
                    except:
                        print("Cannot open the file {} from {} audio folder as it is corrupt".format(file_name,folder_name))
                else:
                    break
    
    return audio_path, features_list

# %%
# Function to save the extracted features into csv file
def save_features_to_csv(features_list, csv_file):
    # define the column names
    column_names = ["chroma_stft", "rmse", "spectral_centroid",
                    "spectral_bandwidth", "spectral_rolloff"] + ["mfcc_{}".format(i) for i in range(1, 21)] + ["target"]
    
    df = pd.DataFrame(features_list, columns=column_names)
    df.to_csv(csv_file, index=False)

# %%
# define the root folder
root_folder = "E:\\personal files\\dataset\\archive_8\\Language Detection Dataset"

# define the csv file
csv_file = "Indian_language_dataset.csv"

audio_path, features_list = process_audio_files(root_folder)
save_features_to_csv(features_list, csv_file)
# Out:
# E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\0.mp3
# Audio Foder: Bengali and File Name: 0.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1.mp3
# Audio Foder: Bengali and File Name: 1.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10.mp3
# Audio Foder: Bengali and File Name: 10.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\100.mp3
# Audio Foder: Bengali and File Name: 100.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1000.mp3
# Audio Foder: Bengali and File Name: 1000.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10000.mp3
# Audio Foder: Bengali and File Name: 10000.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10001.mp3
# Audio Foder: Bengali and File Name: 10001.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10002.mp3
# Audio Foder: Bengali and File Name: 10002.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10003.mp3
# Audio Foder: Bengali and File Name: 10003.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10004.mp3
# Audio Foder: Bengali and File Name: 10004.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10005.mp3
# Audio Foder: Bengali and File Name: 10005.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10006.mp3
# Audio Foder: Bengali and File Name: 10006.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10007.mp3
# Audio Foder: Bengali and File Name: 10007.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10008.mp3
# Audio Foder: Bengali and File Name: 10008.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10009.mp3
# Audio Foder: Bengali and File Name: 10009.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1001.mp3
# Audio Foder: Bengali and File Name: 1001.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10010.mp3
# Audio Foder: Bengali and File Name: 10010.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10011.mp3
# Audio Foder: Bengali and File Name: 10011.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10012.mp3
# Audio Foder: Bengali and File Name: 10012.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10013.mp3
# Audio Foder: Bengali and File Name: 10013.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10014.mp3
# Audio Foder: Bengali and File Name: 10014.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10015.mp3
# Audio Foder: Bengali and File Name: 10015.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10016.mp3
# Audio Foder: Bengali and File Name: 10016.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10017.mp3
# Audio Foder: Bengali and File Name: 10017.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10018.mp3
# Audio Foder: Bengali and File Name: 10018.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10019.mp3
# Audio Foder: Bengali and File Name: 10019.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1002.mp3
# Audio Foder: Bengali and File Name: 1002.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10020.mp3
# Audio Foder: Bengali and File Name: 10020.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10021.mp3
# Audio Foder: Bengali and File Name: 10021.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10022.mp3
# Audio Foder: Bengali and File Name: 10022.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10023.mp3
# Audio Foder: Bengali and File Name: 10023.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10024.mp3
# Audio Foder: Bengali and File Name: 10024.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10025.mp3
# Audio Foder: Bengali and File Name: 10025.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10026.mp3
# Audio Foder: Bengali and File Name: 10026.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10027.mp3
# Audio Foder: Bengali and File Name: 10027.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10028.mp3
# Audio Foder: Bengali and File Name: 10028.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10029.mp3
# Audio Foder: Bengali and File Name: 10029.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1003.mp3
# Audio Foder: Bengali and File Name: 1003.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10030.mp3
# Audio Foder: Bengali and File Name: 10030.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10031.mp3
# Audio Foder: Bengali and File Name: 10031.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10032.mp3
# Audio Foder: Bengali and File Name: 10032.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10033.mp3
# Audio Foder: Bengali and File Name: 10033.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10034.mp3
# Audio Foder: Bengali and File Name: 10034.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10035.mp3
# Audio Foder: Bengali and File Name: 10035.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10036.mp3
# Audio Foder: Bengali and File Name: 10036.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10037.mp3
# Audio Foder: Bengali and File Name: 10037.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10038.mp3
# Audio Foder: Bengali and File Name: 10038.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10039.mp3
# Audio Foder: Bengali and File Name: 10039.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1004.mp3
# Audio Foder: Bengali and File Name: 1004.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10040.mp3
# Audio Foder: Bengali and File Name: 10040.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10041.mp3
# Audio Foder: Bengali and File Name: 10041.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10042.mp3
# Audio Foder: Bengali and File Name: 10042.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10043.mp3
# Audio Foder: Bengali and File Name: 10043.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10044.mp3
# Audio Foder: Bengali and File Name: 10044.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10045.mp3
# Audio Foder: Bengali and File Name: 10045.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10046.mp3
# Audio Foder: Bengali and File Name: 10046.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10047.mp3
# Audio Foder: Bengali and File Name: 10047.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10048.mp3
# Audio Foder: Bengali and File Name: 10048.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10049.mp3
# Audio Foder: Bengali and File Name: 10049.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1005.mp3
# Audio Foder: Bengali and File Name: 1005.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10050.mp3
# Audio Foder: Bengali and File Name: 10050.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10051.mp3
# Audio Foder: Bengali and File Name: 10051.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10052.mp3
# Audio Foder: Bengali and File Name: 10052.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10053.mp3
# Audio Foder: Bengali and File Name: 10053.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10054.mp3
# Audio Foder: Bengali and File Name: 10054.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10055.mp3
# Audio Foder: Bengali and File Name: 10055.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10056.mp3
# Audio Foder: Bengali and File Name: 10056.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10057.mp3
# Audio Foder: Bengali and File Name: 10057.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10058.mp3
# Audio Foder: Bengali and File Name: 10058.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10059.mp3
# Audio Foder: Bengali and File Name: 10059.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1006.mp3
# Audio Foder: Bengali and File Name: 1006.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10060.mp3
# Audio Foder: Bengali and File Name: 10060.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10061.mp3
# Audio Foder: Bengali and File Name: 10061.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10062.mp3
# Audio Foder: Bengali and File Name: 10062.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10063.mp3
# Audio Foder: Bengali and File Name: 10063.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10064.mp3
# Audio Foder: Bengali and File Name: 10064.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10065.mp3
# Audio Foder: Bengali and File Name: 10065.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10066.mp3
# Audio Foder: Bengali and File Name: 10066.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10067.mp3
# Audio Foder: Bengali and File Name: 10067.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10068.mp3
# Audio Foder: Bengali and File Name: 10068.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10069.mp3
# Audio Foder: Bengali and File Name: 10069.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1007.mp3
# Audio Foder: Bengali and File Name: 1007.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10070.mp3
# Audio Foder: Bengali and File Name: 10070.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10071.mp3
# Audio Foder: Bengali and File Name: 10071.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10072.mp3
# Audio Foder: Bengali and File Name: 10072.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10073.mp3
# Audio Foder: Bengali and File Name: 10073.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10074.mp3
# Audio Foder: Bengali and File Name: 10074.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10075.mp3
# Audio Foder: Bengali and File Name: 10075.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10076.mp3
# Audio Foder: Bengali and File Name: 10076.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10077.mp3
# Audio Foder: Bengali and File Name: 10077.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10078.mp3
# Audio Foder: Bengali and File Name: 10078.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10079.mp3
# Audio Foder: Bengali and File Name: 10079.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1008.mp3
# Audio Foder: Bengali and File Name: 1008.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10080.mp3
# Audio Foder: Bengali and File Name: 10080.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10081.mp3
# Audio Foder: Bengali and File Name: 10081.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10082.mp3
# Audio Foder: Bengali and File Name: 10082.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10083.mp3
# Audio Foder: Bengali and File Name: 10083.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10084.mp3
# Audio Foder: Bengali and File Name: 10084.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10085.mp3
# Audio Foder: Bengali and File Name: 10085.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10086.mp3
# Audio Foder: Bengali and File Name: 10086.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10087.mp3
# Audio Foder: Bengali and File Name: 10087.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10088.mp3
# Audio Foder: Bengali and File Name: 10088.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10089.mp3
# Audio Foder: Bengali and File Name: 10089.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1009.mp3
# Audio Foder: Bengali and File Name: 1009.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10090.mp3
# Audio Foder: Bengali and File Name: 10090.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10091.mp3
# Audio Foder: Bengali and File Name: 10091.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10092.mp3
# Audio Foder: Bengali and File Name: 10092.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10093.mp3
# Audio Foder: Bengali and File Name: 10093.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10094.mp3
# Audio Foder: Bengali and File Name: 10094.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10095.mp3
# Audio Foder: Bengali and File Name: 10095.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10096.mp3
# Audio Foder: Bengali and File Name: 10096.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10097.mp3
# Audio Foder: Bengali and File Name: 10097.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10098.mp3
# Audio Foder: Bengali and File Name: 10098.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10099.mp3
# Audio Foder: Bengali and File Name: 10099.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\101.mp3
# Audio Foder: Bengali and File Name: 101.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1010.mp3
# Audio Foder: Bengali and File Name: 1010.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10100.mp3
# Audio Foder: Bengali and File Name: 10100.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10101.mp3
# Audio Foder: Bengali and File Name: 10101.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10102.mp3
# Audio Foder: Bengali and File Name: 10102.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10103.mp3
# Audio Foder: Bengali and File Name: 10103.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10104.mp3
# Audio Foder: Bengali and File Name: 10104.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10105.mp3
# Audio Foder: Bengali and File Name: 10105.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10106.mp3
# Audio Foder: Bengali and File Name: 10106.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10107.mp3
# Audio Foder: Bengali and File Name: 10107.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10108.mp3
# Audio Foder: Bengali and File Name: 10108.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10109.mp3
# Audio Foder: Bengali and File Name: 10109.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1011.mp3
# Audio Foder: Bengali and File Name: 1011.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10110.mp3
# Audio Foder: Bengali and File Name: 10110.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10111.mp3
# Audio Foder: Bengali and File Name: 10111.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10112.mp3
# Audio Foder: Bengali and File Name: 10112.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10113.mp3
# Audio Foder: Bengali and File Name: 10113.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10114.mp3
# Audio Foder: Bengali and File Name: 10114.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10115.mp3
# Audio Foder: Bengali and File Name: 10115.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10116.mp3
# Audio Foder: Bengali and File Name: 10116.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10117.mp3
# Audio Foder: Bengali and File Name: 10117.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10118.mp3
# Audio Foder: Bengali and File Name: 10118.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10119.mp3
# Audio Foder: Bengali and File Name: 10119.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1012.mp3
# Audio Foder: Bengali and File Name: 1012.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10120.mp3
# Audio Foder: Bengali and File Name: 10120.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10121.mp3
# Audio Foder: Bengali and File Name: 10121.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10122.mp3
# Audio Foder: Bengali and File Name: 10122.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10123.mp3
# Audio Foder: Bengali and File Name: 10123.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10124.mp3
# Audio Foder: Bengali and File Name: 10124.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10125.mp3
# Audio Foder: Bengali and File Name: 10125.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10126.mp3
# Audio Foder: Bengali and File Name: 10126.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10127.mp3
# Audio Foder: Bengali and File Name: 10127.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10128.mp3
# Audio Foder: Bengali and File Name: 10128.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10129.mp3
# Audio Foder: Bengali and File Name: 10129.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1013.mp3
# Audio Foder: Bengali and File Name: 1013.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10130.mp3
# Audio Foder: Bengali and File Name: 10130.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10131.mp3
# Audio Foder: Bengali and File Name: 10131.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10132.mp3
# Audio Foder: Bengali and File Name: 10132.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10133.mp3
# Audio Foder: Bengali and File Name: 10133.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10134.mp3
# Audio Foder: Bengali and File Name: 10134.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10135.mp3
# Audio Foder: Bengali and File Name: 10135.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10136.mp3
# Audio Foder: Bengali and File Name: 10136.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10137.mp3
# Audio Foder: Bengali and File Name: 10137.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10138.mp3
# Audio Foder: Bengali and File Name: 10138.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10139.mp3
# Audio Foder: Bengali and File Name: 10139.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1014.mp3
# Audio Foder: Bengali and File Name: 1014.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10140.mp3
# Audio Foder: Bengali and File Name: 10140.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10141.mp3
# Audio Foder: Bengali and File Name: 10141.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10142.mp3
# Audio Foder: Bengali and File Name: 10142.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10143.mp3
# Audio Foder: Bengali and File Name: 10143.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10144.mp3
# Audio Foder: Bengali and File Name: 10144.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10145.mp3
# Audio Foder: Bengali and File Name: 10145.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10146.mp3
# Audio Foder: Bengali and File Name: 10146.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10147.mp3
# Audio Foder: Bengali and File Name: 10147.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10148.mp3
# Audio Foder: Bengali and File Name: 10148.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10149.mp3
# Audio Foder: Bengali and File Name: 10149.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1015.mp3
# Audio Foder: Bengali and File Name: 1015.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10150.mp3
# Audio Foder: Bengali and File Name: 10150.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10151.mp3
# Audio Foder: Bengali and File Name: 10151.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10152.mp3
# Audio Foder: Bengali and File Name: 10152.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10153.mp3
# Audio Foder: Bengali and File Name: 10153.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10154.mp3
# Audio Foder: Bengali and File Name: 10154.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10155.mp3
# Audio Foder: Bengali and File Name: 10155.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10156.mp3
# Audio Foder: Bengali and File Name: 10156.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10157.mp3
# Audio Foder: Bengali and File Name: 10157.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10158.mp3
# Audio Foder: Bengali and File Name: 10158.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10159.mp3
# Audio Foder: Bengali and File Name: 10159.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1016.mp3
# Audio Foder: Bengali and File Name: 1016.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10160.mp3
# Audio Foder: Bengali and File Name: 10160.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10161.mp3
# Audio Foder: Bengali and File Name: 10161.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10162.mp3
# Audio Foder: Bengali and File Name: 10162.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10163.mp3
# Audio Foder: Bengali and File Name: 10163.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10164.mp3
# Audio Foder: Bengali and File Name: 10164.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10165.mp3
# Audio Foder: Bengali and File Name: 10165.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10166.mp3
# Audio Foder: Bengali and File Name: 10166.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10167.mp3
# Audio Foder: Bengali and File Name: 10167.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10168.mp3
# Audio Foder: Bengali and File Name: 10168.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10169.mp3
# Audio Foder: Bengali and File Name: 10169.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1017.mp3
# Audio Foder: Bengali and File Name: 1017.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10170.mp3
# Audio Foder: Bengali and File Name: 10170.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10171.mp3
# Audio Foder: Bengali and File Name: 10171.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10172.mp3
# Audio Foder: Bengali and File Name: 10172.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10173.mp3
# Audio Foder: Bengali and File Name: 10173.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10174.mp3
# Audio Foder: Bengali and File Name: 10174.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10175.mp3
# Audio Foder: Bengali and File Name: 10175.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10176.mp3
# Audio Foder: Bengali and File Name: 10176.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10177.mp3
# Audio Foder: Bengali and File Name: 10177.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10178.mp3
# Audio Foder: Bengali and File Name: 10178.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10179.mp3
# Audio Foder: Bengali and File Name: 10179.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1018.mp3
# Audio Foder: Bengali and File Name: 1018.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10180.mp3
# Audio Foder: Bengali and File Name: 10180.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10181.mp3
# Audio Foder: Bengali and File Name: 10181.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10182.mp3
# Audio Foder: Bengali and File Name: 10182.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10183.mp3
# Audio Foder: Bengali and File Name: 10183.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10184.mp3
# Audio Foder: Bengali and File Name: 10184.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10185.mp3
# Audio Foder: Bengali and File Name: 10185.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10186.mp3
# Audio Foder: Bengali and File Name: 10186.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10187.mp3
# Audio Foder: Bengali and File Name: 10187.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10188.mp3
# Audio Foder: Bengali and File Name: 10188.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10189.mp3
# Audio Foder: Bengali and File Name: 10189.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1019.mp3
# Audio Foder: Bengali and File Name: 1019.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10190.mp3
# Audio Foder: Bengali and File Name: 10190.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10191.mp3
# Audio Foder: Bengali and File Name: 10191.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10192.mp3
# Audio Foder: Bengali and File Name: 10192.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10193.mp3
# Audio Foder: Bengali and File Name: 10193.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10194.mp3
# Audio Foder: Bengali and File Name: 10194.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10195.mp3
# Audio Foder: Bengali and File Name: 10195.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10196.mp3
# Audio Foder: Bengali and File Name: 10196.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10197.mp3
# Audio Foder: Bengali and File Name: 10197.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10198.mp3
# Audio Foder: Bengali and File Name: 10198.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10199.mp3
# Audio Foder: Bengali and File Name: 10199.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\102.mp3
# Audio Foder: Bengali and File Name: 102.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1020.mp3
# Audio Foder: Bengali and File Name: 1020.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10200.mp3
# Audio Foder: Bengali and File Name: 10200.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10201.mp3
# Audio Foder: Bengali and File Name: 10201.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10202.mp3
# Audio Foder: Bengali and File Name: 10202.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10203.mp3
# Audio Foder: Bengali and File Name: 10203.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10204.mp3
# Audio Foder: Bengali and File Name: 10204.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10205.mp3
# Audio Foder: Bengali and File Name: 10205.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10206.mp3
# Audio Foder: Bengali and File Name: 10206.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10207.mp3
# Audio Foder: Bengali and File Name: 10207.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10208.mp3
# Audio Foder: Bengali and File Name: 10208.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10209.mp3
# Audio Foder: Bengali and File Name: 10209.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1021.mp3
# Audio Foder: Bengali and File Name: 1021.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10210.mp3
# Audio Foder: Bengali and File Name: 10210.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10211.mp3
# Audio Foder: Bengali and File Name: 10211.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10212.mp3
# Audio Foder: Bengali and File Name: 10212.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10213.mp3
# Audio Foder: Bengali and File Name: 10213.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10214.mp3
# Audio Foder: Bengali and File Name: 10214.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10215.mp3
# Audio Foder: Bengali and File Name: 10215.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10216.mp3
# Audio Foder: Bengali and File Name: 10216.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10217.mp3
# Audio Foder: Bengali and File Name: 10217.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10218.mp3
# Audio Foder: Bengali and File Name: 10218.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10219.mp3
# Audio Foder: Bengali and File Name: 10219.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1022.mp3
# Audio Foder: Bengali and File Name: 1022.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10220.mp3
# Audio Foder: Bengali and File Name: 10220.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10221.mp3
# Audio Foder: Bengali and File Name: 10221.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10222.mp3
# Audio Foder: Bengali and File Name: 10222.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10223.mp3
# Audio Foder: Bengali and File Name: 10223.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10224.mp3
# Audio Foder: Bengali and File Name: 10224.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10225.mp3
# Audio Foder: Bengali and File Name: 10225.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10226.mp3
# Audio Foder: Bengali and File Name: 10226.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10227.mp3
# Audio Foder: Bengali and File Name: 10227.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10228.mp3
# Audio Foder: Bengali and File Name: 10228.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10229.mp3
# Audio Foder: Bengali and File Name: 10229.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1023.mp3
# Audio Foder: Bengali and File Name: 1023.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10230.mp3
# Audio Foder: Bengali and File Name: 10230.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10231.mp3
# Audio Foder: Bengali and File Name: 10231.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10232.mp3
# Audio Foder: Bengali and File Name: 10232.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10233.mp3
# Audio Foder: Bengali and File Name: 10233.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10234.mp3
# Audio Foder: Bengali and File Name: 10234.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10235.mp3
# Audio Foder: Bengali and File Name: 10235.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10236.mp3
# Audio Foder: Bengali and File Name: 10236.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10237.mp3
# Audio Foder: Bengali and File Name: 10237.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10238.mp3
# Audio Foder: Bengali and File Name: 10238.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10239.mp3
# Audio Foder: Bengali and File Name: 10239.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1024.mp3
# Audio Foder: Bengali and File Name: 1024.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10240.mp3
# Audio Foder: Bengali and File Name: 10240.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10241.mp3
# Audio Foder: Bengali and File Name: 10241.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10242.mp3
# Audio Foder: Bengali and File Name: 10242.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10243.mp3
# Audio Foder: Bengali and File Name: 10243.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10244.mp3
# Audio Foder: Bengali and File Name: 10244.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10245.mp3
# Audio Foder: Bengali and File Name: 10245.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10246.mp3
# Audio Foder: Bengali and File Name: 10246.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10247.mp3
# Audio Foder: Bengali and File Name: 10247.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10248.mp3
# Audio Foder: Bengali and File Name: 10248.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10249.mp3
# Audio Foder: Bengali and File Name: 10249.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1025.mp3
# Audio Foder: Bengali and File Name: 1025.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10250.mp3
# Audio Foder: Bengali and File Name: 10250.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10251.mp3
# Audio Foder: Bengali and File Name: 10251.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10252.mp3
# Audio Foder: Bengali and File Name: 10252.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10253.mp3
# Audio Foder: Bengali and File Name: 10253.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\10254.mp3
# Audio Foder: Bengali and File Name: 10254.mp3 is successfully extracted
# ...
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17648.mp3
# Audio Foder: Bengali and File Name: 17648.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17649.mp3
# Audio Foder: Bengali and File Name: 17649.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1765.mp3
# Audio Foder: Bengali and File Name: 1765.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17650.mp3
# Audio Foder: Bengali and File Name: 17650.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17651.mp3
# Audio Foder: Bengali and File Name: 17651.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17652.mp3
# Audio Foder: Bengali and File Name: 17652.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17653.mp3
# Audio Foder: Bengali and File Name: 17653.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17654.mp3
# Audio Foder: Bengali and File Name: 17654.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17655.mp3
# Audio Foder: Bengali and File Name: 17655.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17656.mp3
# Audio Foder: Bengali and File Name: 17656.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17657.mp3
# Audio Foder: Bengali and File Name: 17657.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17658.mp3
# Audio Foder: Bengali and File Name: 17658.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17659.mp3
# Audio Foder: Bengali and File Name: 17659.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1766.mp3
# Audio Foder: Bengali and File Name: 1766.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17660.mp3
# Audio Foder: Bengali and File Name: 17660.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17661.mp3
# Audio Foder: Bengali and File Name: 17661.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17662.mp3
# Audio Foder: Bengali and File Name: 17662.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17663.mp3
# Audio Foder: Bengali and File Name: 17663.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17664.mp3
# Audio Foder: Bengali and File Name: 17664.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17665.mp3
# Audio Foder: Bengali and File Name: 17665.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17666.mp3
# Audio Foder: Bengali and File Name: 17666.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17667.mp3
# Audio Foder: Bengali and File Name: 17667.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17668.mp3
# Audio Foder: Bengali and File Name: 17668.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17669.mp3
# Audio Foder: Bengali and File Name: 17669.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1767.mp3
# Audio Foder: Bengali and File Name: 1767.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17670.mp3
# Audio Foder: Bengali and File Name: 17670.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17671.mp3
# Audio Foder: Bengali and File Name: 17671.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17672.mp3
# Audio Foder: Bengali and File Name: 17672.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17673.mp3
# Audio Foder: Bengali and File Name: 17673.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17674.mp3
# Audio Foder: Bengali and File Name: 17674.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17675.mp3
# Audio Foder: Bengali and File Name: 17675.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17676.mp3
# Audio Foder: Bengali and File Name: 17676.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17677.mp3
# Audio Foder: Bengali and File Name: 17677.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17678.mp3
# Audio Foder: Bengali and File Name: 17678.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17679.mp3
# Audio Foder: Bengali and File Name: 17679.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1768.mp3
# Audio Foder: Bengali and File Name: 1768.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17680.mp3
# Audio Foder: Bengali and File Name: 17680.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17681.mp3
# Audio Foder: Bengali and File Name: 17681.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17682.mp3
# Audio Foder: Bengali and File Name: 17682.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17683.mp3
# Audio Foder: Bengali and File Name: 17683.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17684.mp3
# Audio Foder: Bengali and File Name: 17684.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17685.mp3
# Audio Foder: Bengali and File Name: 17685.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17686.mp3
# Audio Foder: Bengali and File Name: 17686.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17687.mp3
# Audio Foder: Bengali and File Name: 17687.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17688.mp3
# Audio Foder: Bengali and File Name: 17688.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17689.mp3
# Audio Foder: Bengali and File Name: 17689.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1769.mp3
# Audio Foder: Bengali and File Name: 1769.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17690.mp3
# Audio Foder: Bengali and File Name: 17690.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17691.mp3
# Audio Foder: Bengali and File Name: 17691.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17692.mp3
# Audio Foder: Bengali and File Name: 17692.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17693.mp3
# Audio Foder: Bengali and File Name: 17693.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17694.mp3
# Audio Foder: Bengali and File Name: 17694.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17695.mp3
# Audio Foder: Bengali and File Name: 17695.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17696.mp3
# Audio Foder: Bengali and File Name: 17696.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17697.mp3
# Audio Foder: Bengali and File Name: 17697.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17698.mp3
# Audio Foder: Bengali and File Name: 17698.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17699.mp3
# Audio Foder: Bengali and File Name: 17699.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\177.mp3
# Audio Foder: Bengali and File Name: 177.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1770.mp3
# Audio Foder: Bengali and File Name: 1770.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17700.mp3
# Audio Foder: Bengali and File Name: 17700.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17701.mp3
# Audio Foder: Bengali and File Name: 17701.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17702.mp3
# Audio Foder: Bengali and File Name: 17702.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17703.mp3
# Audio Foder: Bengali and File Name: 17703.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17704.mp3
# Audio Foder: Bengali and File Name: 17704.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17705.mp3
# Audio Foder: Bengali and File Name: 17705.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17706.mp3
# Audio Foder: Bengali and File Name: 17706.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17707.mp3
# Audio Foder: Bengali and File Name: 17707.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17708.mp3
# Audio Foder: Bengali and File Name: 17708.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17709.mp3
# Audio Foder: Bengali and File Name: 17709.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1771.mp3
# Audio Foder: Bengali and File Name: 1771.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17710.mp3
# Audio Foder: Bengali and File Name: 17710.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17711.mp3
# Audio Foder: Bengali and File Name: 17711.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17712.mp3
# Audio Foder: Bengali and File Name: 17712.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17713.mp3
# Audio Foder: Bengali and File Name: 17713.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17714.mp3
# Audio Foder: Bengali and File Name: 17714.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17715.mp3
# Audio Foder: Bengali and File Name: 17715.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17716.mp3
# Audio Foder: Bengali and File Name: 17716.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17717.mp3
# Audio Foder: Bengali and File Name: 17717.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17718.mp3
# Audio Foder: Bengali and File Name: 17718.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17719.mp3
# Audio Foder: Bengali and File Name: 17719.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1772.mp3
# Audio Foder: Bengali and File Name: 1772.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17720.mp3
# Audio Foder: Bengali and File Name: 17720.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17721.mp3
# Audio Foder: Bengali and File Name: 17721.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17722.mp3
# Audio Foder: Bengali and File Name: 17722.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17723.mp3
# Audio Foder: Bengali and File Name: 17723.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17724.mp3
# Audio Foder: Bengali and File Name: 17724.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17725.mp3
# Audio Foder: Bengali and File Name: 17725.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17726.mp3
# Audio Foder: Bengali and File Name: 17726.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17727.mp3
# Audio Foder: Bengali and File Name: 17727.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17728.mp3
# Audio Foder: Bengali and File Name: 17728.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17729.mp3
# Audio Foder: Bengali and File Name: 17729.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\1773.mp3
# Audio Foder: Bengali and File Name: 1773.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17730.mp3
# Audio Foder: Bengali and File Name: 17730.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17731.mp3
# Audio Foder: Bengali and File Name: 17731.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17732.mp3
# Audio Foder: Bengali and File Name: 17732.mp3 is successfully extracted
# audio_path:-  E:\personal files\dataset\archive_8\Language Detection Dataset\Bengali\17733.mp3
